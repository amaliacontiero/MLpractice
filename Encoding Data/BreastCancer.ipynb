# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from keras.models import Sequential
from keras.layers import Dense

# %%
def load_dataset(filename):
    data = pd.read_csv(filename, header=None)
    dataset = data.values
    #split to input x and output y
    x = dataset[:,:-1]
    y = dataset[:,-1]

    x = x.astype(str) #format values as string
    y = y.reshape((len(y),1)) #reshape target to 2d array

    return x, y

# %%
x, y = load_dataset('breast-cancer.csv')
#split intro train and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=1)

# %%
print('Train', x_train.shape, y_train.shape)
print('Test', x_test.shape, y_test.shape)
# Out:
# Train (191, 9) (191, 1)
# Test (95, 9) (95, 1)

# %% [markdown]
# We have 191 samples for training and 95 for testing.

# %%
def input_prep(x_train, x_test):
    oe = sklpre.OrdinalEncoder()
    oe.fit(x_train)
    x_train_enc = oe.transform(x_train)
    x_test_enc = oe.transform(x_test)
    return x_train_enc, x_test_enc

# %%
def output_prep(y_train, y_test):
    le = sklpre.LabelEncoder()
    le.fit(y_train)
    y_train_enc = le.transform(y_train)
    y_test_enc = le.transform(y_test)
    return y_train_enc, y_test_enc

# %%
x_train_enc, x_test_enc = input_prep(x_train, x_test)
y_train_enc, y_test_enc = output_prep(y_train, y_test)

# %% [markdown]
# Neural Network Model:

# %%
# define the model
model = Sequential()
model.add(Dense(10, input_dim=x_train_enc.shape[1], activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1, activation='sigmoid'))
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(x_train_enc, y_train_enc, epochs=100, batch_size=16, verbose=2)
# evaluate the keras model
_, accuracy = model.evaluate(x_test_enc, y_test_enc, verbose=0)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/100
# 12/12 - 1s - loss: 0.8825 - accuracy: 0.3194 - 534ms/epoch - 45ms/step
# Epoch 2/100
# 12/12 - 0s - loss: 0.8202 - accuracy: 0.3822 - 15ms/epoch - 1ms/step
# Epoch 3/100
# 12/12 - 0s - loss: 0.7730 - accuracy: 0.4398 - 15ms/epoch - 1ms/step
# Epoch 4/100
# 12/12 - 0s - loss: 0.7358 - accuracy: 0.5131 - 15ms/epoch - 1ms/step
# Epoch 5/100
# 12/12 - 0s - loss: 0.7090 - accuracy: 0.6021 - 17ms/epoch - 1ms/step
# Epoch 6/100
# 12/12 - 0s - loss: 0.6872 - accuracy: 0.6283 - 19ms/epoch - 2ms/step
# Epoch 7/100
# 12/12 - 0s - loss: 0.6696 - accuracy: 0.6492 - 18ms/epoch - 2ms/step
# Epoch 8/100
# 12/12 - 0s - loss: 0.6577 - accuracy: 0.6649 - 16ms/epoch - 1ms/step
# Epoch 9/100
# 12/12 - 0s - loss: 0.6459 - accuracy: 0.6754 - 16ms/epoch - 1ms/step
# Epoch 10/100
# 12/12 - 0s - loss: 0.6363 - accuracy: 0.6806 - 16ms/epoch - 1ms/step
# Epoch 11/100
# 12/12 - 0s - loss: 0.6275 - accuracy: 0.6963 - 15ms/epoch - 1ms/step
# Epoch 12/100
# 12/12 - 0s - loss: 0.6205 - accuracy: 0.6963 - 15ms/epoch - 1ms/step
# Epoch 13/100
# 12/12 - 0s - loss: 0.6137 - accuracy: 0.7016 - 16ms/epoch - 1ms/step
# Epoch 14/100
# 12/12 - 0s - loss: 0.6077 - accuracy: 0.7016 - 16ms/epoch - 1ms/step
# Epoch 15/100
# 12/12 - 0s - loss: 0.6031 - accuracy: 0.7120 - 14ms/epoch - 1ms/step
# Epoch 16/100
# 12/12 - 0s - loss: 0.5968 - accuracy: 0.7277 - 16ms/epoch - 1ms/step
# Epoch 17/100
# 12/12 - 0s - loss: 0.5920 - accuracy: 0.7277 - 15ms/epoch - 1ms/step
# Epoch 18/100
# 12/12 - 0s - loss: 0.5878 - accuracy: 0.7330 - 15ms/epoch - 1ms/step
# Epoch 19/100
# 12/12 - 0s - loss: 0.5838 - accuracy: 0.7330 - 18ms/epoch - 1ms/step
# Epoch 20/100
# 12/12 - 0s - loss: 0.5797 - accuracy: 0.7382 - 17ms/epoch - 1ms/step
# Epoch 21/100
# 12/12 - 0s - loss: 0.5761 - accuracy: 0.7382 - 17ms/epoch - 1ms/step
# Epoch 22/100
# 12/12 - 0s - loss: 0.5728 - accuracy: 0.7382 - 18ms/epoch - 2ms/step
# Epoch 23/100
# 12/12 - 0s - loss: 0.5695 - accuracy: 0.7435 - 19ms/epoch - 2ms/step
# Epoch 24/100
# 12/12 - 0s - loss: 0.5660 - accuracy: 0.7435 - 21ms/epoch - 2ms/step
# Epoch 25/100
# 12/12 - 0s - loss: 0.5634 - accuracy: 0.7435 - 15ms/epoch - 1ms/step
# Epoch 26/100
# 12/12 - 0s - loss: 0.5607 - accuracy: 0.7435 - 16ms/epoch - 1ms/step
# Epoch 27/100
# 12/12 - 0s - loss: 0.5577 - accuracy: 0.7435 - 15ms/epoch - 1ms/step
# Epoch 28/100
# 12/12 - 0s - loss: 0.5553 - accuracy: 0.7382 - 14ms/epoch - 1ms/step
# Epoch 29/100
# 12/12 - 0s - loss: 0.5530 - accuracy: 0.7382 - 14ms/epoch - 1ms/step
# Epoch 30/100
# 12/12 - 0s - loss: 0.5507 - accuracy: 0.7382 - 14ms/epoch - 1ms/step
# Epoch 31/100
# 12/12 - 0s - loss: 0.5484 - accuracy: 0.7382 - 14ms/epoch - 1ms/step
# Epoch 32/100
# 12/12 - 0s - loss: 0.5466 - accuracy: 0.7382 - 14ms/epoch - 1ms/step
# Epoch 33/100
# 12/12 - 0s - loss: 0.5445 - accuracy: 0.7382 - 15ms/epoch - 1ms/step
# Epoch 34/100
# 12/12 - 0s - loss: 0.5431 - accuracy: 0.7382 - 12ms/epoch - 1ms/step
# Epoch 35/100
# 12/12 - 0s - loss: 0.5415 - accuracy: 0.7382 - 14ms/epoch - 1ms/step
# Epoch 36/100
# 12/12 - 0s - loss: 0.5398 - accuracy: 0.7435 - 17ms/epoch - 1ms/step
# Epoch 37/100
# 12/12 - 0s - loss: 0.5386 - accuracy: 0.7435 - 16ms/epoch - 1ms/step
# Epoch 38/100
# 12/12 - 0s - loss: 0.5371 - accuracy: 0.7435 - 13ms/epoch - 1ms/step
# Epoch 39/100
# 12/12 - 0s - loss: 0.5357 - accuracy: 0.7435 - 16ms/epoch - 1ms/step
# Epoch 40/100
# 12/12 - 0s - loss: 0.5347 - accuracy: 0.7487 - 14ms/epoch - 1ms/step
# Epoch 41/100
# 12/12 - 0s - loss: 0.5336 - accuracy: 0.7539 - 14ms/epoch - 1ms/step
# Epoch 42/100
# 12/12 - 0s - loss: 0